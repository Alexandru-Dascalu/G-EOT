# %% [markdown]
# ## Evaluation G-EOT

# %% [markdown]
# This notebook is used to evaluate the performance of the G-EOT model for black-box adversarial attacks for 3D objects. At the end of this notebook you can see the history of the loss and TFR of the model during training.

# %%
# %run advnet.py
# Out:
# Shape of Noises:  (None, 2048, 2048, 3)
# Model: "generator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 2048, 2048,  0           []
#                                  3)]
#
#  average_pooling2d (AveragePool  (None, 256, 256, 3)  0          ['input_2[0][0]']
#  ing2D)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 32  896         ['average_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 32  128        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  depthwise_conv2d (DepthwiseCon  (None, 128, 128, 64  640        ['batch_normalization_4[0][0]']
#  v2D)                           )
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 64  256        ['depthwise_conv2d[0][0]']
#  rmalization)                   )
#
# ...
